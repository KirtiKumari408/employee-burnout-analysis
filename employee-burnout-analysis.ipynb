# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = r"C:\Users\KIRTI KUMARI\Desktop\employee_burnout_analysis-AI 2.xlsx"
try:
    df = pd.read_excel(data_path, engine='openpyxl')
    print("Dataset loaded successfully!")
    display(df.head())
except FileNotFoundError:
    print("Error: File not found. Please check the file path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Dataset loaded successfully!
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No            2                  3.0                   3.8
# 1                 Yes            1                  2.0                   5.0
# 2                 Yes            2                  NaN                   5.8
# 3                 Yes            1                  1.0                   2.6
# 4                  No            3                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# ...

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
print("\nDataset Info:")
print(df.info())
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Missing values in each column:
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# Resource Allocation     1381
# Mental Fatigue Score    2117
# Burn Rate               1124
# dtype: int64
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  datetime64[ns]
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  int64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
# ...

# %%
df.to_excel(r"C:\Users\KIRTI KUMARI\Desktop\cleaned_employee_burnout_analysis.xlsx", index=False)
print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
print(df.columns)
# Out:
# Index(['Employee ID', 'Date of Joining', 'Gender', 'Company Type',
#        'WFH Setup Available', 'Designation', 'Resource Allocation',
#        'Mental Fatigue Score', 'Burn Rate'],
#       dtype='object')

# %%
df = pd.read_excel(r"C:\Users\KIRTI KUMARI\Desktop\employee_burnout_analysis-AI 2.xlsx")

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Designation', data=df)  # Replace with the actual column name
plt.title("Count Plot of Correct Column")
plt.xticks(rotation=45)  # Rotate labels if needed
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Mental Fatigue Score'], kde=True, bins=20)
plt.title("Distribution of Mental Fatigue Score")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Company Type', y='Burn Rate', data=df)
plt.title("Burn Rate by Company Type")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Resource Allocation', y='Burn Rate', hue='Company Type', data=df)
plt.title("Burn Rate vs Resource Allocation")
plt.show()
